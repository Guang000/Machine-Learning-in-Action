# %%
import numpy as np
import logRegres
from imp import reload

# %%
reload(logRegres)
dataMat, labelMat = logRegres.loadDataSet()

# %%
logRegres.gradAscent(dataMat, labelMat)
# Out:
# matrix([[ 4.12414349],
#         [ 0.48007329],
#         [-0.6168482 ]])

# %%
reload(logRegres)
# Out:
# <module 'logRegres' from 'D:\\Jupyter\\Machine Learning\\Logistic Regression\\logRegres.py'>

# %%
weights = logRegres.gradAscent(dataMat, labelMat)
logRegres.plotBestFit(weights.getA()) #getA()将weights矩阵转换为数组，getA()函数与mat()函数的功能相反

# %%
weights
# Out:
# matrix([[ 4.12414349],
#         [ 0.48007329],
#         [-0.6168482 ]])

# %%
weights.getA()
# Out:
# array([[ 4.12414349],
#        [ 0.48007329],
#        [-0.6168482 ]])

# %%
reload(logRegres)
# Out:
# <module 'logRegres' from 'D:\\Jupyter\\Machine Learning\\Logistic Regression\\logRegres.py'>

# %%
dataArr, labelMat = logRegres.loadDataSet()
weights = logRegres.stocGradAscent(np.array(dataArr), labelMat)
logRegres.plotBestFit(weights)

# %%
reload(logRegres)
# Out:
# <module 'logRegres' from 'D:\\Jupyter\\Machine Learning\\Logistic Regression\\logRegres.py'>

# %%
dataArr, labelMat = logRegres.loadDataSet()
weights = logRegres.stocGradAscentPlus(np.array(dataArr), labelMat)
logRegres.plotBestFit(weights)

# %%
weights = logRegres.stocGradAscentPlus(np.array(dataArr), labelMat, 500)
logRegres.plotBestFit(weights)

# %%
reload(logRegres)
# Out:
# <module 'logRegres' from 'D:\\Jupyter\\Machine Learning\\Logistic Regression\\logRegres.py'>

# %%
logRegres.multiTest()
# Out:
# D:\Jupyter\Machine Learning\Logistic Regression\logRegres.py:28: RuntimeWarning: overflow encountered in exp
#   return 1.0 / (1 + np.exp(-inX))
# The error rate of this test is: 0.417910
# The error rate of this test is: 0.402985
# The error rate of this test is: 0.313433
# The error rate of this test is: 0.402985
# The error rate of this test is: 0.283582
# The error rate of this test is: 0.343284
# The error rate of this test is: 0.417910
# The error rate of this test is: 0.283582
# The error rate of this test is: 0.283582
# The error rate of this test is: 0.402985
# After 10 iteration the average error rate is: 0.355224
